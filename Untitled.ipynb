# %%
import json
  
# Opening JSON file
f = open('OCR/testimage1.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
data
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1,
#      'Height': 0.9986876845359802,
#      'Left': 0,
#      'Top': 0},
#     'Polygon': [{'X': 3.6452377213721585e-17, 'Y': 0},
#      {'X': 1, 'Y': 0},
#      {'X': 1, 'Y': 0.9986876845359802},
#      {'X': 0, 'Y': 0.9986876845359802}]},
#    'Id': 'fbd834eb-cc43-4ecc-ac55-84a48060e749',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0c686105-a850-4310-840b-7dbfe78836e8',
#       '0cb29edf-4a48-468d-af15-1b95f0ea7e4b',
#       '61f51c88-37ee-431c-8ce6-1158caab4200',
#       'e85698e7-42a0-43b1-9076-78e4f1455b63',
#       '9014c89b-4d53-4344-8e3d-be482917f02f',
#       '1c1050fb-04b9-47f8-a24d-e7d79e4bee9f',
#       '677a942e-039b-4148-bcea-cd31ad2f6733',
#       '7d73c0af-29f6-4305-94c8-1d5a719f1465',
#       'ef2f6c3c-d322-4767-9915-aee490d686a9',
#       '3b34836c-f2f1-4420-bc01-ea0c42355aa6',
#       'f8bb3ac5-aa9f-4e29-9393-c1ba25156d2e',
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread('Images/testimage1.jpeg')
 
# Output Images
plt.figure(figsize = (20,8))
plt.imshow(img);

# %%
# Normalization changes the range of pixel intensity values.

from matplotlib import pyplot as plt
import cv2
import numpy as np
norm_img = np.zeros((img.shape[0], img.shape[1]))
img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
plt.figure(figsize = (20,8))
plt.imshow(img)
plt.title('Image')
plt.show()

# %%
erosion = cv2.erode(img, None, iterations=1)
plt.figure(figsize = (20,8))
plt.imshow(erosion)
plt.title('Eroded Image')
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

# im = cv2.imread("./Images/testimage1.jpeg")
color = cv2.cvtColor(erosion, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (20,8))
plt.imshow(color)
plt.title('Image')
plt.show()

# %%
import cv2 as cv
import numpy as np
gray = cv.cvtColor(img, c.COLOR_BGR2GRAY)
thresh = cv.threshold(gray, 0, 255, cv.THRESH_BINARY_INV | cv.THRESH_OTSU)[1]
                          #127,255,cv.THRESH_BINARY_INV)

plt.figure(figsize=(20,8))
plt.imshow(thresh) 
plt.title('Denoised Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-348-4712548a2b18> in <module>
#       1 import cv2 as cv
#       2 import numpy as np
# ----> 3 gray = cv.cvtColor(img, c.COLOR_BGR2GRAY)
#       4 thresh = cv.threshold(gray, 0, 255, cv.THRESH_BINARY_INV | cv.THRESH_OTSU)[1]
#       5                           #127,255,cv.THRESH_BINARY_INV)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'COLOR_BGR2GRAY'

# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image as im
from scipy.ndimage import interpolation as inter

input_file = sys.argv[1]
img = im.open('Images/testimage1.jpeg')

# convert to binary
wd, ht = img.size
pix = np.array(img.convert('1').getdata(), np.uint8)
bin_img = 1 - (pix.reshape((ht, wd)) / 255.0)
plt.figure(figsize=(20,8))
plt.imshow(bin_img, cmap='gray')
plt.savefig('binary.png')
def find_score(arr, angle):
    data = inter.rotate(arr, angle, reshape=False, order=0)
    hist = np.sum(data, axis=1)
    score = np.sum((hist[1:] - hist[:-1]) ** 2)
    return hist, score
delta = 1
limit = 5
angles = np.arange(-limit, limit+delta, delta)
scores = []
for angle in angles:
    hist, score = find_score(bin_img, angle)
    scores.append(score)
best_score = max(scores)
best_angle = angles[scores.index(best_score)]
# correct skew
data = inter.rotate(bin_img, best_angle, reshape=False, order=0)
img = im.fromarray((255 * data).astype("uint8")).convert("RGB")
img.save('skew_corrected.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-9ea4e0aa648d> in <module>
#       9
#      10 # convert to binary
# ---> 11 wd, ht = color.size
#      12 pix = np.array(color.convert('1').getdata(), np.uint8)
#      13 bin_img = 1 - (pix.reshape((ht, wd)) / 255.0)
#
# TypeError: cannot unpack non-iterable int object

# %%
import numpy as np 
import cv2 
from matplotlib import pyplot as plt 
# Reading image from folder where it is stored 

# denoising of image saving it into dst image 
dst = cv2.fastNlMeansDenoisingColored(thresh, None, 10, 10, 7, 15) 
# Plotting of source and destination image
plt.figure(figsize=(20,8))
plt.imshow(dst) 
plt.title('Denoised Image')
plt.show()

# %%
#(h, w) = thresh.shape[:2]
#resize = cv2.resize(dst, (w * 2, h * 2))
dilation = cv2.dilate(thresh, None, iterations=1)
plt.figure(figsize = (20,8))
plt.imshow(dilation)
plt.title('Resized and Dilated Image')
plt.show()

# %%
erosion = cv2.erode(dilation, None, iterations=1)
plt.figure(figsize = (20,8))
plt.imshow(erosion)
plt.title('Eroded Image')
plt.show()

# %%
bnt = cv2.bitwise_not(dst)
plt.figure(figsize = (20,8))
plt.imshow(bnt)
plt.title('Bitwise-Not Image')
plt.show()

# %%
from imutils import contours
import imutils
cnts = cv2.findContours(bnt, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
cnts = imutils.grab_contours(cnts)
digitCnts = []
# loop over the digit area candidates
image_w_bbox = img.copy()
image_w_bbox = imutils.rotate_bound(image_w_bbox, -6)
#print("Printing (x, y, w, h) for each each bounding rectangle found in the image...")
for c in cnts:
  # compute the bounding box of the contour
  (x, y, w, h) = cv2.boundingRect(c)
#  print(x, y, w, h)
# if the contour is sufficiently large, it must be a digit
  if w >= 10 and (h >= 130 and h <= 170):
    digitCnts.append(c)
    image_w_bbox = cv.rectangle(image_w_bbox,(x, y),(x+w, y+h),(0, 255, 0),2)
plt.figure(figsize = (20,8))
plt.imshow(image_w_bbox)
plt.title('Image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-259-5456366c779a> in <module>
#       1 from imutils import contours
#       2 import imutils
# ----> 3 cnts = cv2.findContours(bnt, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
#       4 cnts = imutils.grab_contours(cnts)
#       5 digitCnts = []
#
# error: OpenCV(4.5.4) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgproc/src/contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
edged = cv2.Canny(bnt, 30, 200)
#contours, hierarchy = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
#contours = cv2.drawContours(erosion, contours, -1, (0, 255, 0), 3)
plt.figure(figsize = (20,8))
plt.imshow(edged)
plt.title('Image')
plt.show()

# %%
from pytesseract import pytesseract

path_to_tesseract = r'/opt/homebrew/bin/tesseract'
pytesseract.tesseract_cmd = path_to_tesseract

txt = pytesseract.image_to_string(image, config="--psm 6 digits")
print(txt)
# Out:
# 29
# 61
# 3 1 1
# 220-8922664-10.0-
# 4
# 5 27
# .17

# %%
from WordsToText import img2text as i2t
text = i2t('Images/testimage1.jpeg')
print(text)
# Out:
# “Ladlsolzo | aitaolao lel losaso teat | | tn | saseton | 2
# | sil solzo } ial a0 fae | losset ire | | | a aaco loo |
#
# 9 sulsolzotadaotea Led alesear mec. Lah 26eelool a.
# 4 iltoleotatsoleo teil tessa too | te poss loads
# SL astral: viiolee Lait lesaaz toe | | tt a | p99 too Ly
# Gl of alan | aa apse Lael. lesen Toe | | |b wy 7 yebe la _

# %%
import cv2

image = cv2.imread('Images/testimage1.jpeg')
original = image.copy()
h, w, _ = image.shape

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (15,1))
close = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)

cnts = cv2.findContours(close, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
minimum_area = .75 * h * w
cnts = [c for c in cnts if cv2.contourArea(c) < minimum_area]
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    ROI = 255 - original[y:y+h, x:x+w]
    cv2.rectangle(image, (x, y), (x + w, y + h), (36,255,12), 2)
    break

# %%
plt.figure(figsize = (20,8))
plt.imshow(close)
plt.imshow(image)
plt.imshow(ROI)
plt.show()
